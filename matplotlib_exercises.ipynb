# %% [markdown]
# 1. Plot $y = x^{2} - x + 2$.
#
# - Generate the x and y points.
# - Annotate the origin.

# %%
import matplotlib.pyplot as plt

# %%
x = list(range(-20, 20))

y = [(n ** 2 - n + 2) for n in x]

plt.plot(x, y)
plt.title('$y = x^{2} - x + 2$', fontsize = 14)
plt.annotate('Origin', xy = (0, 0), xytext = (0, 70), arrowprops = {'facecolor': 'purple'})

plt.show()

# %% [markdown]
# 2. a) Plot $y = \sqrt{x}$

# %%
from math import sqrt

x = list(range(0, 20))

y = [sqrt(n) for n in x]

plt.plot(x, y)
plt.title('$y = \sqrt{x}$', fontsize = 14)
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.show()

# %% [markdown]
# b) Plot $y = x^{3}$

# %%
x = list(range(-20, 20))

y = [n ** 3 for n in x]

plt.plot(x, y)
plt.title('$y = x^{3}$')
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.show()

# %% [markdown]
# c) Plot $y = 2^{x}$

# %%
x = list(range(-20, 20))

y = [2 ** n for n in x]

plt.plot(x, y)
plt.title('$y = 2^{x}$')
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.show()

# %% [markdown]
# d) y = 1/(x + 1)

# %%
x = list(range(0, 20))

y = [1 / (n + 1) for n in x]

plt.plot(x, y)
plt.title('$y = {1} / {(n + 1)}$')
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.show()

# %% [markdown]
# 3. Combine the figures you created in the last step into one large figure with 4 subplots

# %%
plt.figure(figsize = (16, 8))

# plot $\sqrt{x}$
plt.subplot(2, 2, 1)

x = list(range(0, 50))
y = [sqrt(n) for n in x]

plt.plot(x, y)
plt.title('$\sqrt{x}$')
plt.ylabel('$y$')


# plot $x^{3}$
plt.subplot(2, 2, 2) 

x = list(range(-10, 10))
y = [n ** 3 for n in x]

plt.plot(x, y)
plt.title('$x^{3}$')
plt.xlabel('$x$')


# plot $2^{x}$
plt.subplot(2, 2, 3) 

x = list(range(-10, 10))
y = [2 ** n for n in x]

plt.plot(x, y)
plt.title('$2^{x}$')
plt.xlabel('$x$')
plt.ylabel('$y$')


# plot $y = {1} / {(n + 1)}$
plt.subplot(2, 2, 4)

x = list(range(0, 10))

y = [1 / (n + 1) for n in x]

plt.plot(x, y)
plt.title('$y = {1} / {(n + 1)}$')
plt.xlabel('$x$')
plt.ylabel('$y$')

plt.tight_layout()

# %% [markdown]
# 4. Combine the figures you created in the last step into one figure where each of the 4 equations has a different color for the points. Be sure to include a legend and an appropriate title for the figure.

# %%
plt.figure(figsize = (10, 6))

x = list(range(0, 30))

y1 = [sqrt(n) for n in x]
y2 = [n**3 for n in x]
y3 = [2**n for n in x]
y4 = [1/(n + 1) for n in x]

plt.plot(x, y1, c='red', label='$\sqrt{x}$', alpha=.5)
plt.plot(x, y2, c='green', label='$x^{3}$', alpha=.5)
plt.plot(x, y3, c='blue', label='$2^{x}$', alpha=.5)
plt.plot(x, y4, c='black', label='${1}/{(n + 1)}$', alpha=.5)
plt.ylim(0, 20)
plt.xlim(0, 20)

plt.ylabel('$y$')
plt.xlabel('$x$')
plt.title('Combined Equations')
plt.legend()

plt.show()
